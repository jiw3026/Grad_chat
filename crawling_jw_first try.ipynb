# %% [markdown]
# <a href="https://colab.research.google.com/github/jiw3026/Grad_chat/blob/main/crawling_jw_first%20try.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install requests

# %%
import requests

# %%
session = requests.session()

# %%
LOGIN_URL = 'https://treepla.net/login?back_url=Lw%3D%3D&used_login_btn=Y'
USERNAME = '박지원'
PASSWORD = 'Newmoon4!'

# %%
login_data = {
    'username' : USERNAME,
    'password': PASSWORD
}

# %%
response = session.post(LOGIN_URL, data = login_data)

# %%
if response.status_code == 200:
  print('로그인 성공')
else :
  print('로그인 실패')
# Out:
# 로그인 성공

# %%
CRAWLING_URL = 'https://treepla.net/magazine?category=31V8M2iV5n'
response = session.get(CRAWLING_URL)
print(response.content)
# Out:
# b'<!DOCTYPE html>\n<html lang="ko">\n<head>\n\n\t<meta charset="utf-8">\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n<meta name="theme-color" content="#06a0f5"/>\n<meta name="msapplication-navbutton-color" content="#06a0f5">\n<meta name="apple-mobile-web-app-status-bar-style" content="black-translucent">\n\n<meta property="og:url" content="https://treepla.net/magazine?category=31V8M2iV5n"/>\n<title>\xec\x88\xb2\xea\xb3\xbc \xeb\x82\x98\xeb\xac\xb4\xec\x97\x90 \xeb\x8c\x80\xed\x95\x9c \xec\x9d\xb4\xec\x95\xbc\xea\xb8\xb0 - \xeb\xa7\xa4\xea\xb1\xb0\xec\xa7\x84</title>\n<meta name=\'application-name\' content=\'\xec\x88\xb2\xea\xb3\xbc \xeb\x82\x98\xeb\xac\xb4\xec\x97\x90 \xeb\x8c\x80\xed\x95\x9c \xec\x9d\xb4\xec\x95\xbc\xea\xb8\xb0 - \xeb\xa7\xa4\xea\xb1\xb0\xec\xa7\x84\'/>\n<meta name=\'msapplication-tooltip\' content=\'\xec\x88\xb2\xea\xb3\xbc \xeb\x82\x98\xeb\xac\xb4\xec\x97\x90 \xeb\x8c\x80\xed\x95\x9c \xec\x9d\xb4\xec\x95\xbc\xea\xb8\xb0 - \xeb\xa7\xa4\xea\xb1\xb0\xec\x
# ...

# %%
import requests
from bs4 import BeautifulSoup

# %%
resp = requests.post(CRAWLING_URL,)

# %%
encoding = response.info().get_content_charset(failobj = 'utf-8')
text = text.read().decode(encoding)
print(text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-95f3760944f2> in <cell line: 1>()
# ----> 1 encoding = response.info().get_content_charset(failobj = 'utf-8')
#       2 text = text.read().decode(encoding)
#       3 print(text)
#
# AttributeError: 'Response' object has no attribute 'info'

# %%
# https://treepla.net/partnership
# energ.onee@gmail.com
# Newmoon4!
